# %%
# Python  : Basics, Operators ,Conditions , Loops , Sequences [List, Dictionary], Comprehension etc. 
# Library : pandas, numpy. 
# Statistic Basics

# %%
# Application :

# Exploratory Data Analysis  : 2-3 Projects    [basics of Python  , revise Libraries ] 
# Data Cleaning              : EDA + Data Cleaning  [1-2 Projcts ]
# Data Pre Processing        : [1-2 Projects]

# Supervised ML Algorithms : 
#              A. Regression      4-6 Projects 
#              B. Classification  8-10 Projects 
# Unsupervised ML Algorithms : 

# 
# 1. Recommender Systems           
# 2. Computer Vision             : Images , Videos etc.
# 3. Natural Language Processing :  Basics , Projects 

# Ensemble learning

# %%
# Revision :

# %%
# Step - 1  : Import Libraries 

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\91930\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Step :2 : Read Data 

df = pd.read_excel('superstore.xls')

# %%
# 1. Identify total number of Rows and Columns.

df.shape      # Rows = 9994   Columns = 21
# Out:
# (9994, 21)

# %%
# 2. Display Customer ID and Customer Name.

df[['Customer ID', 'Customer Name']]   # Column Selection
# Out:
#      Customer ID     Customer Name
# 0       CG-12520       Claire Gute
# 1       CG-12520       Claire Gute
# 2       DV-13045   Darrin Van Huff
# 3       SO-20335    Sean O'Donnell
# 4       SO-20335    Sean O'Donnell
# ...          ...               ...
# 9989    TB-21400  Tom Boeckenhauer
# 9990    DB-13060       Dave Brooks
# 9991    DB-13060       Dave Brooks
# 9992    DB-13060       Dave Brooks
# 9993    CC-12220      Chris Cortes
#
# [9994 rows x 2 columns]

# %%
# 3. Display first 10 rows.

df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
# 4. Display last 10 Rows.

df.tail(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
# 5. Display random 5 rows.

df.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 540      541  CA-2014-140795 2014-02-01 2014-02-03     First Class
# 2733    2734  CA-2014-107594 2014-07-02 2014-07-06  Standard Class
# 5244    5245  CA-2016-156265 2016-08-02 2016-08-04    Second Class
# 2681    2682  CA-2017-127026 2017-01-21 2017-01-27  Standard Class
# 2875    2876  US-2016-167339 2016-01-21 2016-01-23    Second Class
#
#      Customer ID      Customer Name      Segment        Country         City  \
# 540     BD-11500    Bradley Drucker     Consumer  United States    Green Bay
# 2733    EH-13945      Eric Hoffmann     Consumer  United States   Plainfield
# 5244    BF-11020  Barry Französisch    Corporate  United States  Los Angeles
# 2681    MH-18115     Mick Hernandez  Home Office  United States      Jackson
# 2875    TD-20995      Tamara Dahlen     Consumer  United States    San Diego
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
# 6. Display rows from 100 to 150.

df.iloc[ 101 : 151]
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 101     102  CA-2016-158568 2016-08-29 2016-09-02  Standard Class    RB-19465
# 102     103  CA-2016-129903 2016-12-01 2016-12-04    Second Class    GZ-14470
# 103     104  US-2015-156867 2015-11-13 2015-11-17  Standard Class    LC-16870
# 104     105  US-2015-156867 2015-11-13 2015-11-17  Standard Class    LC-16870
# 105     106  US-2015-156867 2015-11-13 2015-11-17  Standard Class    LC-16870
# 106     107  CA-2017-119004 2017-11-23 2017-11-28  Standard Class    JM-15250
# 107     108  CA-2017-119004 2017-11-23 2017-11-28  Standard Class    JM-15250
# 108     109  CA-2017-119004 2017-11-23 2017-11-28  Standard Class    JM-15250
# 109     110  CA-2015-129476 2015-10-15 2015-10-20  Standard Class    PA-19060
# 110     111  CA-2017-146780 2017-12-25 2017-12-30  Standard Class    CV-12805
# 111     112  CA-2016-128867 2016-11-03 2016-11-10  Standard Class    CL-12565
# ...

# %%
# 7. Display Name of customers from 2000 to 2010 row.

df.iloc[2000 : 2011]['Customer Name']
# Out:
# 2000          Luke Weiss
# 2001          Luke Weiss
# 2002      Joni Wasserman
# 2003      Joni Wasserman
# 2004    Sample Company A
# 2005        Rob Williams
# 2006        Rob Williams
# 2007    Charlotte Melton
# 2008        Jamie Frazer
# 2009        Jamie Frazer
# 2010        Jamie Frazer
# Name: Customer Name, dtype: object

# %%
# 8. Identify total count of customers.

df['Customer ID'].nunique()
# Out:
# 793

# %%
# 9. Identify total Columns.

df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# 10. Identify data types of columns.

df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('superstore.xls')

# %%
# Display unique value in
# ship mode,segment,country,city,state,Region,category,sub-categories,product

# %%
# !pip install xlrd

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
# 1> state total count and unique
df['State'].unique(),df['State'].nunique()
# Out:
# (array(['Kentucky', 'California', 'Florida', 'North Carolina',
#         'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#         'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#         'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#         'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#         'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#         'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#         'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#         'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#         'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#         'West Virginia'], dtype=object),
#  49)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
# sub-category
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
# 9> product name
df['Product Name'].unique(),df['Product Name'].nunique()
# Out:
# (array(['Bush Somerset Collection Bookcase',
#         'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#         'Self-Adhesive Address Labels for Typewriters by Universal', ...,
#         'Eureka Hand Vacuum, Bagless', 'LG G2',
#         'Eldon Jumbo ProFile Portable File Boxes Graphite/Black'],
#        dtype=object),
#  1850)

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %%
#2 > Display count of deliveries and thier percentage per
# 1> segment  2> city  3> state  4> Region  5> category  6> sub category

# %%
# 1> segment
round(df['Segment'].value_counts()/df.shape[0]*100,2)
# Out:
# Segment
# Consumer       51.94
# Corporate      30.22
# Home Office    17.84
# Name: count, dtype: float64

# %%
round(df['Segment'].value_counts()/df.shape[0]*100,2).plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df['City'].value_counts()[ :10]
# Out:
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Name: count, dtype: int64

# %%
round(df['City'].value_counts()/df.shape[0]*100,2)
# Out:
# City
# New York City      9.16
# Los Angeles        7.47
# Philadelphia       5.37
# San Francisco      5.10
# Seattle            4.28
#                    ...
# Glenview           0.01
# Missouri City      0.01
# Rochester Hills    0.01
# Palatine           0.01
# Manhattan          0.01
# Name: count, Length: 531, dtype: float64

# %%
df['City'].value_counts()[: 10].plot.barh()
# Out:
# <Axes: ylabel='City'>

# %%
df['State'].value_counts()[:10]
# Out:
# State
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: count, dtype: int64

# %%
round(df['State'].value_counts()/df.shape[0]*100,2)
# Out:
# State
# California              20.02
# New York                11.29
# Texas                    9.86
# Pennsylvania             5.87
# Washington               5.06
# Illinois                 4.92
# Ohio                     4.69
# Florida                  3.83
# Michigan                 2.55
# North Carolina           2.49
# Arizona                  2.24
# Virginia                 2.24
# Georgia                  1.84
# Tennessee                1.83
# Colorado                 1.82
# Indiana                  1.49
# Kentucky                 1.39
# Massachusetts            1.35
# New Jersey               1.30
# Oregon                   1.24
# Wisconsin                1.10
# Maryland                 1.05
# Delaware                 0.96
# Minnesota                0.89
# Connecticut              0.82
# Oklahoma                 0.66
# Missouri                 0.66
# Alabama                  0.61
# Arkansas                 0.60
# Rhode Island             0.56
# Utah                     0.53
# ...

# %%
df['State'].value_counts()[:10].plot.barh()
# Out:
# <Axes: ylabel='State'>

# %%
df['State'].value_counts()[:10].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
round(df['Segment'].value_counts()/df['Segment'].shape*100,2)
# Out:
# Segment
# Consumer       51.94
# Corporate      30.22
# Home Office    17.84
# Name: count, dtype: float64

# %%
round(df['Segment'].value_counts()/df['Segment'].shape*100,2).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
# 4> Region

df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
round(df['Region'].value_counts()/df['Region'].shape*100,2)
# Out:
# Region
# West       32.05
# East       28.50
# Central    23.24
# South      16.21
# Name: count, dtype: float64

# %%
round(df['Region'].value_counts()/df['Region'].shape[0]*100,2).plot.barh()
# Out:
# <Axes: ylabel='Region'>

# %%
round(df['Region'].value_counts()/df['Region'].shape[0]*100,2).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
round(df['Category'].value_counts()/df['Category'].shape[0]*100,2).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['Category'].value_counts()/df['Category'].shape[0]
# Out:
# Category
# Office Supplies    0.602962
# Furniture          0.212227
# Technology         0.184811
# Name: count, dtype: float64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# 3. Display count  of Techonology for each region

df[['Category','Region']][df.Category=='Technology']['Region'].value_counts()
# Out:
# Region
# West       599
# East       535
# Central    420
# South      293
# Name: count, dtype: int64

# %%
# 4> Display Top 10 cities with office supplies

df[df.Category=='Office Supplies']['City'].value_counts()[:10]
# Out:
# City
# New York City    552
# Los Angeles      443
# San Francisco    322
# Philadelphia     312
# Seattle          249
# Houston          231
# Chicago          187
# Columbus         135
# Dallas           104
# Springfield      104
# Name: count, dtype: int64

# %%
# 5> Display count of each segment for state california 

df[df.State == 'California']['Segment'].value_counts()
# Out:
# Segment
# Consumer       1048
# Corporate       618
# Home Office     335
# Name: count, dtype: int64

# %%
# 6> Display top 5 state with sales of office supplies

df[df.Category=='Office Supplies']['State'].value_counts()[:5]
# Out:
# State
# California      1198
# New York         684
# Texas            604
# Pennsylvania     343
# Washington       292
# Name: count, dtype: int64

# %%
# 7> Display Top 3 sub categories for furniture

df[df.Category == 'Furniture']['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Furnishings    957
# Chairs         617
# Tables         319
# Bookcases      228
# Name: count, dtype: int64

# %%
# 1. Display Total Sales of Technology from Region = East.
# 2. Display Total Sales from office Supplies from Consumers.
# 3. Display TOtal Sales by Customer  Dave Brooks , Claire Gute.
# 4. Display Total Phone Sales from States Florida, California.
# 5. Display Total Sales from Corporates with 'Same Day' delivery in east and west reagion.

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# 1. Display Total Sales of Technology from Region = East.

df[(df.Category=='Technology') &  (df.Region=='East')]['Sales'].sum().round(2)
# Out:
# 264973.98

# %%
# 2. Display Total Sales from office Supplies from Consumers.

df[(df.Category=='Office Supplies') & (df.Segment=='Consumer')]['Sales'].sum().round(2)
# Out:
# 363952.14

# %%
# 3. Display TOtal Sales by Customer  Dave Brooks , Claire Gute.

df[(df['Customer Name']=='Dave Brooks') | (df['Customer Name']=='Claire Gute')]['Sales'].sum().round(2)
# Out:
# 5680.43

# %%
# 4. Display Total Phone Sales from States Florida, California.
df[(df['State']=='Californi') | (df['State']=='Florida') & (df['Sub-Category']=='Phones')]['Sales'].sum().round(2)
# Out:
# 15092.18

# %%
# 5. Display Total Sales from Corporates with 'Same Day' delivery in east and west reagion.

df([df.Segment]  =='Corprate') & (df['Ship Mode']=='Same Day')) & (df['Ship Mode']=='Same Day')
& ((df.Region == 'East')| (df.Region == 'West')) ][['Segment','Ship Mode','Region','Sales']]['Sales'].sum().round(2)
# Out:
#   Cell In[73], line 3
#     df([df.Segment]  =='Corprate') & (df['Ship Mode']=='Same Day')) & (df['Ship Mode']=='Same Day')
#                                                                   ^
# SyntaxError: unmatched ')'

# %%
# groupby
# Find and dispay Total sales and Total Profit for 
# 1> Each segment    2> Each State   3> Each region   4> category

# %%
df1=df.groupby('Segment')[['Sales','Profit']].sum().round(2)

# %%
df1
# Out:
#                   Sales     Profit
# Segment
# Consumer     1161401.34  134119.21
# Corporate     706146.37   91979.13
# Home Office   429653.15   60298.68

# %%
df1['% Profit']=round(df1['Profit']/df1['Sales']*100,2)

# %%
df1
# Out:
#                   Sales     Profit  % Profit
# Segment
# Consumer     1161401.34  134119.21     11.55
# Corporate     706146.37   91979.13     13.03
# Home Office   429653.15   60298.68     14.03

# %%
df1.plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df1[['Sales','Profit']].plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
# Region

df.groupby('Region')[['Sales','Profit']].sum().round(2)


df.groupby('Region')[['Sales','Profit']].sum().round(2).plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
# State

df.groupby('State')[['Sales','Profit']].sum().round(2)
# Out:
#                           Sales    Profit
# State
# Alabama                19510.64   5786.83
# Arizona                35282.00  -3427.92
# Arkansas               11678.13   4008.69
# California            457687.63  76381.39
# Colorado               32108.12  -6527.86
# Connecticut            13384.36   3511.49
# Delaware               27451.07   9977.37
# District of Columbia    2865.02   1059.59
# Florida                89473.71  -3399.30
# Georgia                49095.84  16250.04
# Idaho                   4382.49    826.72
# Illinois               80166.10 -12607.89
# Indiana                53555.36  18382.94
# Iowa                    4579.76   1183.81
# Kansas                  2914.31    836.44
# Kentucky               36591.75  11199.70
# Louisiana               9217.03   2196.10
# Maine                   1270.53    454.49
# Maryland               23705.52   7031.18
# Massachusetts          28634.43   6785.50
# Michigan               76269.61  24463.19
# ...

# %%
# Category

df.groupby('Category')[['Sales','Profit']].sum().round(2)


df.groupby('Category')[['Sales','Profit']].sum().round(2).plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
#  1>  Find and Display region wise sales and profit of 'Furniture'

# %%
df[df.Category=='Furniture'].groupby('Region')[['Profit','Sales']].sum().round(2)
# Out:
#            Profit      Sales
# Region
# Central  -2871.05  163797.16
# East      3046.17  208291.20
# South     6771.21  117298.68
# West     11504.95  252612.74

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# 1. Find and Display region wise sales and profit of 'Furniture'
# 2. Find and Display Top 5 Cities with sales for state = 'Florida'
# 3. Find and Display total sales and profit for products with NO Discount.
# 4. Display Sales and profit of cities with above average city sales

# %%
# 2. Find and Display Top 5 Cities with sales for state = 'Florida'

df[df.State == 'Florida'].groupby('City')['Sales'].sum().sort_values(ascending=False)[:10]
# Out:
# City
# Jacksonville        39133.3280
# Miami                8673.0745
# Tallahassee          7250.6690
# Lakeland             5606.8865
# Tampa                5196.0805
# Fort Lauderdale      4929.5325
# Hialeah              2338.9490
# Orlando              1740.0800
# Pembroke Pines       1714.3755
# Saint Petersburg     1690.7920
# Name: Sales, dtype: float64

# %%
# 3. Find and Display total sales and profit for products with NO Discount.

df[df.Discount ==0][['Profit','Sales']].sum().round(2)
# Out:
# Profit     320987.60
# Sales     1087908.47
# dtype: float64

# %%
# 4. Display Sales and profit of cities with above average city sales

df['Sales'].sum()/df['City'].nunique()
# Out:
# 4326.178644632769

# %%
df1=df.groupby('City')['Sales'].sum()

# %%
df1[df1.values > 4326]
# Out:
# City
# Alexandria         5519.570
# Anaheim            7986.870
# Arlington         20214.532
# Atlanta           17197.840
# Aurora            11656.478
#                     ...
# Tucson             6313.016
# Tulsa              5556.970
# Virginia Beach     5752.130
# Wilmington         7297.061
# Yonkers            7657.666
# Name: Sales, Length: 92, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\91930\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r'C:\Users\91930\Downloads\train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Display total number of rows
df.shape[0]
# Out:
# 891

# %%
# display first 10 rows
df.iloc[:10]
#  OR
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Display last 10 rows
df.tail(10)



# df.iloc[-10:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Display all columns name


df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 5> Display  random 10 rows


df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 680          681         0       3            Peters, Miss. Katie  female
# 653          654         1       3  O'Leary, Miss. Hanora "Norah"  female
# 792          793         0       3        Sage, Miss. Stella Anna  female
# 644          645         1       3         Baclini, Miss. Eugenie  female
# 482          483         0       3       Rouse, Mr. Richard Henry    male
# 522          523         0       3             Lahoud, Mr. Sarkis    male
# 424          425         0       3    Rosblom, Mr. Viktor Richard    male
# 545          546         0       1   Nicholson, Mr. Arthur Ernest    male
# 853          854         1       1      Lines, Miss. Mary Conover  female
# 722          723         0       2   Gillespie, Mr. William Henry    male
#
#        Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 680    NaN      0      0    330935   8.1375   NaN        Q
# ...

# %%
# 6> Display rows from 100 to 125

df.iloc[100:126]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 100          101         0       3            Petranec, Miss. Matilda  female
# 101          102         0       3   Petroff, Mr. Pastcho ("Pentcho")    male
# 102          103         0       1          White, Mr. Richard Frasar    male
# 103          104         0       3         Johansson, Mr. Gustaf Joel    male
# 104          105         0       3     Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3              Mionoff, Mr. Stoytcho    male
# 106          107         1       3   Salkjelsvik, Miss. Anna Kristine  female
# 107          108         1       3             Moss, Mr. Albert Johan    male
# 108          109         0       3                    Rekic, Mr. Tido    male
# 109          110         1       3                Moran, Miss. Bertha  female
# 110          111         0       1     Porter, Mr. Walter Chamberlain    male
# ...

# %%
# 7> Display name,sex,age,survival status of passenger

df[['PassengerId','Survived','Name','Sex','Age']]
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#         Sex   Age
# ...

# %%
# 8> Display name,age ,sex of MAles



df[df.Sex =='male'][['Name','Age','Sex']]
# Out:
#                                Name   Age   Sex
# 0           Braund, Mr. Owen Harris  22.0  male
# 4          Allen, Mr. William Henry  35.0  male
# 5                  Moran, Mr. James   NaN  male
# 6           McCarthy, Mr. Timothy J  54.0  male
# 7    Palsson, Master. Gosta Leonard   2.0  male
# ..                              ...   ...   ...
# 883   Banfield, Mr. Frederick James  28.0  male
# 884          Sutehall, Mr. Henry Jr  25.0  male
# 886           Montvila, Rev. Juozas  27.0  male
# 889           Behr, Mr. Karl Howell  26.0  male
# 890             Dooley, Mr. Patrick  32.0  male
#
# [577 rows x 3 columns]

# %%
# Display passanger traveling in first class



df[df.Pclass ==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 10 >  Display average fare

df['Fare'].mean().round(2)
# Out:
# 32.2

# %%
# 11> Display datatype  of  all columns

df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# display continous columns
# display categorical columns
cat = []
cont = []
for i in df.columns :
    #print(i)
    if df[i].nunique() >= 10 :
        cont.append(i)    # continous features / columns
    else :
        cat.append(i)
        
print('continous : ', cont)
print('categorical : ',cat)
# Out:
# continous :  ['PassengerId', 'Name', 'Age', 'Ticket', 'Fare', 'Cabin']
# categorical :  ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

# %%
# Display class of each categorical columns
for i in cat:
    print(i,"\t",df[i].unique())
# Out:
# Survived 	 [0 1]
# Pclass 	 [3 1 2]
# Sex 	 ['male' 'female']
# SibSp 	 [1 0 3 4 2 5 8]
# Parch 	 [0 1 2 5 3 4 6]
# Embarked 	 ['S' 'C' 'Q' nan]

# %%
# Display columns with null value

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Sex'].nunique()
# Out:
# 2

# %%
# 16 Display count of servived / non servived 
df['Survived'].value_counts()


# in percentage
# df['Survived'].value_counts()/891 *100
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: count, dtype: float64

# %%
# 17>  Display count of male /female

df['Sex'].value_counts().plot.pie()

df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Disply count of passenger in each class

df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# Display count of each embarked

df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Display mean ,median of age of passenger

print("Mean :",df['Age'].mean().round(2))
print("Median :",df['Age'].median().round(2))
# Out:
# Mean : 29.7
# Median : 28.0

# %%
#  0 :-> survived         1: -.> survived

# Diplay name of all not survived passanger

df[df.Survived == 0]['Name']

# %%
# Display  of all females who survived

df[(df.Survived == 1) & (df.Sex =='female')][['Name','Sex','Survived']]
# Out:
# 0                       Braund, Mr. Owen Harris
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 6                       McCarthy, Mr. Timothy J
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 884                      Sutehall, Mr. Henry Jr
# 885        Rice, Mrs. William (Margaret Norton)
# 886                       Montvila, Rev. Juozas
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 549, dtype: object

# %%
# display of all males  travelling in class I who survived

df[(df.Survived ==1) & (df.Sex == 'male') & (df.Pclass ==1)][['Name','Sex','Survived','Pclass']]
# Out:
#                                               Name   Sex  Survived  Pclass
# 23                    Sloper, Mr. William Thompson  male         1       1
# 55                               Woolner, Mr. Hugh  male         1       1
# 97                 Greenfield, Mr. William Bertram  male         1       1
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")  male         1       1
# 209                               Blank, Mr. Henry  male         1       1
# 224                   Hoyt, Mr. Frederick Maxfield  male         1       1
# 248                  Beckwith, Mr. Richard Leonard  male         1       1
# 298                          Saalfeld, Mr. Adolphe  male         1       1
# 305                 Allison, Master. Hudson Trevor  male         1       1
# 370                    Harder, Mr. George Achilles  male         1       1
# 390                     Carter, Mr. William Ernest  male         1       1
# ...

# %%
# display of female with age> 50 that survived



df[(df.Survived ==1)  & (df.Sex=='female') & (df.Age>=50)][['Name','Sex','Survived','Pclass','Age']]
# Out:
#                                                   Name     Sex  Survived  \
# 11                            Bonnell, Miss. Elizabeth  female         1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female         1
# 195                               Lurette, Miss. Elise  female         1
# 259                        Parrish, Mrs. (Lutie Davis)  female         1
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female         1
# 275                  Andrews, Miss. Kornelia Theodosia  female         1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female         1
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female         1
# 458                                Toomey, Miss. Ellen  female         1
# 483                             Turkula, Mrs. (Hedwig)  female         1
# 496                     Eustis, Miss. Elizabeth Mussey  female         1
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female         1
# ...

# %%
# display survived status of all passanger teavelling in class


df[df.Pclass == 1]['Survived'].value_counts()
# Out:
# Survived
# 1    136
# 0     80
# Name: count, dtype: int64

# %%
# Display survival ststus of all passengers travelling in class II

df[df.Pclass ==2]['Survived'].value_counts()/df[df.Pclass == 1]['Survived'].value_counts().sum()*100

#  Display survival stof all passengers travelling in class II
# Display survived
# Out:
# Survived
# 0    44.907407
# 1    40.277778
# Name: count, dtype: float64

# %%
# Disply Survived status of all passenger travelling in class III
df[df.Pclass == 3]['Survived'].value_counts()/df[df.Pclass == 3]['Survived'].value_counts().sum()*100
# Out:
# Survived
# 0    75.763747
# 1    24.236253
# Name: count, dtype: float64

# %%
#  Display Survived Status of pasenger who paid more than median fig of tickt

df[df.Fare >= df['Fare'].median()]['Survived'].value_counts()
# Out:
# Survived
# 1    231
# 0    220
# Name: count, dtype: int64

# %%
# Display sex wise survived status of passenger

df.groupby('Sex')['Survived'].value_counts().unstack()
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
# Display passenger class  sex wise survival status

df.groupby(['Pclass','Sex'])['Survived'].value_counts().unstack()
# Out:
# Survived         0   1
# Pclass Sex
# 1      female    3  91
#        male     77  45
# 2      female    6  70
#        male     91  17
# 3      female   72  72
#        male    300  47

# %%
# Import all Libraries 


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\91930\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
